# %%
with open('life-expectancy.csv', 'r') as f:
    lines = f.readlines()
    rows = []
    for line in lines:
        s = line.split(',') 
        rows.append(s)

# %%
lf = []
for row in rows[1:]:
    lf.append(float(row[3].strip()))

# %%
min(lf)
# Out:
# 17.76

# %%
year = '1999'

def get_average(lst: list) -> list:
    return sum(lst) / len(lst)
max_value = max([ [float(row[3].strip()), row[0], row[2] ] for row in rows])
min_value = min([ [float(row[3].strip()), row[0], row[2] ] for row in rows])
all_life = [ float(row[3].strip()) for row in rows ]
average = get_average(all_life)
top3 = sorted([ [float(row[3].strip()), row[0], row[2] ] for row in rows], reverse=True)[:3]

# %%
top3
# Out:
# [[86.751, 'Monaco', '2019'],
#  [86.56, 'Monaco', '2018'],
#  [86.325, 'Monaco', '2017']]

# %%
max_value
# Out:
# [86.751, 'Monaco', '2019']

# %%
import pandas as pd
df = pd.DataFrame(dataframe)

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
year_list = [row[2] for row in rows]
averages = {}
for row in rows:
    for year in year_list:
        if row[2] == year:
            averages.update({year:row[3]})

# %%
averages
# Out:
# {'1950': '48.831\n',
#  '1951': '49.04\n',
#  '1952': '49.46\n',
#  '1953': '49.886\n',
#  '1954': '50.317\n',
#  '1955': '50.754\n',
#  '1956': '51.197\n',
#  '1957': '51.645\n',
#  '1958': '52.098\n',
#  '1959': '52.556\n',
#  '1960': '53.019\n',
#  '1961': '53.483\n',
#  '1962': '53.946\n',
#  '1963': '54.403\n',
#  '1964': '54.849\n',
#  '1965': '55.274\n',
#  '1966': '55.671\n',
#  '1967': '56.034\n',
#  '1968': '56.362\n',
#  '1969': '56.656\n',
#  '1970': '56.913\n',
#  '1971': '57.135\n',
#  '1972': '57.329\n',
#  '1973': '57.509\n',
#  '1974': '57.688\n',
#  '1975': '57.892\n',
#  '1976': '58.15\n',
#  '1977': '58.47\n',
#  '1978': '58.85\n',
#  '1979': '59.274\n',
#  '1980': '59.731\n',
#  '1981': '60.203\n',
#  '1982': '60.65\n',
#  '1983': '61.025\n',
#  '1984': '61.28\n',
#  '1985': '61.356\n',
#  '1986': '61.199\n',
#  '1987': '60.792\n',
#  '1988': '60.136\n',
#  '1989': '59.235\n',
#  '1990': '58.1\n',
#  '1991': '56.749\n',
#  '1992': '55.243\n',
# ...
